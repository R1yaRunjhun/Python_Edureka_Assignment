# %% [markdown]
# 1. You are given a dataset, which is present in the LMS, containing the number of hurricanes occurring in the United States along the coast of the Atlantic. Load the data from the dataset into your program and plot a Bar Graph of the data, taking
# the Year as the X-axis and the number of hurricanes occurring as the Y-axis.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Hurricanes =pd.read_csv("Hurricanes.csv")
Hurricanes.head()
# Out:
#    Year  Hurricanes
# 0  1914           0
# 1  1915           5
# 2  1916          10
# 3  1917           2
# 4  1918           4

# %%
plt.figure(figsize=(10,6))
plt.bar(Hurricanes['Year'],Hurricanes['Hurricanes'])
plt.xlabel("Year")
plt.ylabel("Frequency of Hurricanes")
# Out:
# Text(0, 0.5, 'Frequency of Hurricanes')

# %% [markdown]
# 2. The given dataset records the data of city temperatures over the years 2014 and 2015. Plot the histogram of the temperatures over this period for the cities of San Francisco and Moscow

# %%
city_temp =pd.read_csv("CityTemps.csv")

# %%
x_mosco = city_temp["Moscow"]
x_san_Francisco = city_temp["San Francisco"]
plt.hist(x_mosco, len(x_mosco), facecolor='blue', alpha=1.0)
plt.hist(x_san_Francisco, len(x_san_Francisco), facecolor='red', alpha=1.0)
plt.xlabel("Temperature")
plt.ylabel("Frequency")
plt.title("Temperatures of Mosco and San Francisco")
# Out:
# Text(0.5, 1.0, 'Temperatures of Mosco and San Francisco')

# %% [markdown]
# 3. Plot a pie-chart of the number of models released by every manufacturer, recorded in the provided data. Also, mention the name of the manufacturer with the largest releases.

# %%
df = pd.read_csv('Cars2015.csv')
#drop the column which are not require.
df = df.drop(['Model','Type','LowPrice','HighPrice','Drive','CityMPG','HwyMPG','FuelCap','Length'], axis=1)
df = df.drop(['Width','Wheelbase','Height','UTurn','Weight','Acc030','Acc060'],axis=1)
df = df.drop(['QtrMile','PageNum','Size'],axis=1)
m_dict =dict()
for Make in set(df.Make):
    m_dict[Make]=df[df.Make==Make].Make.count()
print(m_dict)
plt.figure(figsize=(15,15))
plt.pie(m_dict.values(),labels=m_dict.keys())
plt.show()
# Out:
# {'Volkswagon': 3, 'Lexus': 2, 'Subaru': 3, 'Mazda': 3, 'Nissan': 6, 'Dodge': 2, 'Buick ': 1, 'Maserati': 1, 'Buick': 3, 'Kia': 5, 'Ford ': 1, 'Audi': 6, 'Chrysler': 3, 'Mitsubishi': 1, 'Mercedes': 2, 'GMC ': 2, 'Infiniti': 2, 'Acura': 2, 'Jeep': 2, 'Scion': 2, 'Porche': 2, 'Chevrolet': 8, 'Dodge ': 3, 'Mazda ': 1, 'Toyoto': 7, 'Fiat': 1, 'Cadillac': 4, 'Honda ': 4, 'Lincoln': 2, 'Ford': 7, 'BMW': 5, 'Volvo': 2, 'Hyundai': 7, 'Subaru ': 1, 'Land Rover': 1, 'Jaguar': 2, 'Chevrolet ': 1}

# %% [markdown]
# 4. Create a CSV file from the data provided below.
#
# Phase 1 -Read the data
#
# Phase 2 –Describe the data
#
# Describe the data on the unit price.
#
# Phase 3 –Filter the data
# Create a new DataFrame having columns as name, net_price, date, and group all the records according to name.
#
# Phase 4 –Plotting graph
# Plot the graph after calculating the total sales by each customer. The customer name should be on the X-axis and total saleson the Y-axis.

# %%
df_sales =pd.read_csv("sample-salesv2.csv")
df_sales['unit price'].describe()
# Out:
# count    1000.000000
# mean       56.179630
# std        25.331939
# min        10.060000
# 25%        35.995000
# 50%        56.765000
# 75%        76.802500
# max        99.970000
# Name: unit price, dtype: float64

# %%
df_sales_new = df_sales.filter(['name','net_price','date'], axis=1)
for group,data in df_sales_new.groupby('name'):
    print("group:", group)
    print("data", data)
# Out:
# group: Berge LLC
# data           name  net_price              date
# 23   Berge LLC     231.00  04-11-2013 09:48
# 60   Berge LLC     299.64  04-08-2014 23:08
# 87   Berge LLC     280.00  22-11-2013 17:45
# 95   Berge LLC     542.26  26-10-2013 17:03
# 119  Berge LLC     644.40  27-09-2014 02:51
# 153  Berge LLC     448.14  05-11-2013 03:55
# 162  Berge LLC     937.70  17-08-2014 09:21
# 163  Berge LLC     508.38  20-07-2014 18:27
# 172  Berge LLC     896.83  01-09-2014 17:46
# 190  Berge LLC     394.56  12-12-2013 00:57
# 212  Berge LLC     171.12  12-03-2014 11:43
# 222  Berge LLC     445.90  04-05-2014 18:52
# 276  Berge LLC    1683.78  29-01-2014 06:44
# 292  Berge LLC     124.64  12-03-2014 11:38
# 309  Berge LLC     882.75  22-08-2014 04:35
# 317  Berge LLC     704.10  23-05-2014 13:09
# 319  Berge LLC      67.84  27-06-2014 15:53
# 329  Berge LLC     326.97  15-06-2014 15:52
# 333  Berge LLC    1156.50  07-12-2013 11:53
# 340  Berge LLC    1073.76  23-05-2014 06:43
# ...

# %%
import matplotlib.pyplot as plt

# %%
df_sales["Total Price"] = df_sales["quantity"] * df_sales["unit price"]
df_sales.head(10)
plt.figure(figsize=(8,6))
df_sales.groupby("name").sum()['Total Price'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='name'>

# %% [markdown]
# 5. Let the X-axis and Y-axis data points be as the following:
#
# X = [1,2,3,4]
#
# y = [20, 21, 20.5, 20.8]
#
# 5.1: Draw a simple plot
#
# 5.2: Configure the line and markers in a simple plot
#
# 5.3: Configure the axes
#
# 5.4: Give the title to the graph & labels of the X-axis and Y-axis.
#
# 5.5: Give the error bar if y_error = [0.12, 0.13, 0.2, 0.1]
#
# 5.6: Define width, height as figsize=(4,5) DPI and adjust plot dpi=100
#
# 5.7: Give a font size of 14
#
# 5.8: Draw a scatter graph of any 50 random values across X and Y axes
#
# 5.9: Create a DataFrame from the following data:
# 'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#
# 'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#
# 'female': [0, 1, 1, 0, 1],
#
# 'age': [42, 52, 36, 24, 73],
#
# 'preTestScore': [4, 24, 31, 2, 3],
#
# 'postTestScore': [25, 94, 57, 62, 70]
#
# Draw a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age.
#
# 5.10: Draw a Scatterplot from the data in question 9 of preTestScore and postTestScore with the size = 300 and the color determined by sex

# %%
X = [1,2,3,4]
Y = [20, 21, 20.5, 20.8]

# %%
plt.plot(X,Y)
plt.show()

# %%
plt.plot(X, Y)
plt.grid()
plt.show()

# %%
plt.setp(plt.gca().get_xticklabels(), rotation=90,
         horizontalalignment='right')
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
plt.plot(X, Y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
y_error = [0.12, 0.13, 0.2, 0.1]

plt.plot(X, Y, y_error)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
plt.figure(figsize=(3, 4))

# %%
plt.rcParams.update({'font.size': 14})

# %%
import numpy as np
x = np.random.random(50)
y = np.random.random(50)

plt.scatter(x, y)
plt.show()

# %%
df = pd.DataFrame({
    'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
    'female': [0, 1, 1, 0, 1],
    'age': [42, 52, 36, 24, 73],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70]
})

plt.scatter(df["preTestScore"], df["postTestScore"])
plt.xlabel("preTestScore")
plt.ylabel("postTestScore")
plt.title("preTestScore vs postTestScore")
plt.legend(["preTestScore", "postTestScore"])
plt.show()

# %%
df = pd.DataFrame({
    'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
    'female': [0, 1, 1, 0, 1],
    'age': [42, 52, 36, 24, 73],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70]
})

x = df["preTestScore"]
y = df["postTestScore"]
colors = df["female"]

plt.scatter(x, y, c=colors, alpha=0.5)
plt.xlabel("preTestScore")
plt.ylabel("postTestScore")
plt.title("preTestScore vs postTestScore")
plt.legend(["preTestScore", "postTestScore"])
plt.show()
